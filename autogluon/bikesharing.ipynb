# %% [markdown]
# # Udacity's AWS AI ML Course Project I
# <hr/>
#
# ## Submitted by Abhijith Ganesh
#
# [Kaggle Link](https://www.kaggle.com/c/bike-sharing-demand/overview)

# %% [markdown]
# Uses AutoGluon

# %%
# !pip install -U pandas scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from datetime import datetime
import os

# %%
# Get current directory pathlib

directory = os.getcwd() + "/dataset"
test_set = pd.read_csv(directory + "/test.csv")
train_set = pd.read_csv(directory + "/train.csv")

# %%
test_set.describe()
# Out:
#             season      holiday   workingday      weather         temp
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000  \
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed
# count  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157
# std       8.782741    19.293391     8.250151
# min       0.000000    16.000000     0.000000
# 25%      16.665000    49.000000     7.001500
# 50%      25.000000    65.000000    11.001400
# ...

# %%
test_set.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365  \
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
test_set["datetime"] = pd.to_datetime(test_set["datetime"])

# %% [markdown]
# ## Notes from the dataset
#
# - The dataset has only one variable stored as string (datetime) and it needs to be converted to datetime format
#
# ## Null Values exist in:
# - Windspeed

# %%
test_set.corr()
# Out:
#             datetime    season   holiday  workingday   weather      temp
# datetime    1.000000  0.275389  0.020884   -0.003417 -0.030518  0.061189  \
# season      0.275389  1.000000 -0.075759    0.051488 -0.053554  0.401384
# holiday     0.020884 -0.075759  1.000000   -0.255820 -0.033279 -0.071852
# workingday -0.003417  0.051488 -0.255820    1.000000  0.062447  0.096519
# weather    -0.030518 -0.053554 -0.033279    0.062447  1.000000 -0.179034
# temp        0.061189  0.401384 -0.071852    0.096519 -0.179034  1.000000
# atemp       0.064187  0.410626 -0.072373    0.103202 -0.185746  0.991936
# humidity   -0.034914  0.083792 -0.031611    0.059599  0.437406 -0.081734
# windspeed  -0.052798 -0.154507 -0.003240   -0.053690  0.057360 -0.030990
#
#                atemp  humidity  windspeed
# datetime    0.064187 -0.034914  -0.052798
# season      0.410626  0.083792  -0.154507
# holiday    -0.072373 -0.031611  -0.003240
# workingday  0.103202  0.059599  -0.053690
# ...
